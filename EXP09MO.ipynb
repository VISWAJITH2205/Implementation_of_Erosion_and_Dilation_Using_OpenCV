# %% [markdown]
# # Ex. No: 09
# ## Implementation of Erosion and Dilation Using OpenCV
#
# **Name :** VISWAJITH LALITHRAM R.V  **Reg. No :** 212224240187    **Slot No :** 26OD1143

# %% [markdown]
# # Morphological Operators

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_img():
    blank_img = np.zeros((200, 560), dtype=np.uint8)
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(blank_img,text='VISWAJITH',org=(22,160),fontFace=font,fontScale= 5,color=(255,255,255),thickness=25,lineType=cv2.LINE_AA)
    return blank_img

# %%
def display_img(img):
    fig = plt.figure(figsize=(8.4, 3))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap="gray")
    plt.show()

# %%
img = load_img()

# %%
display_img(img)

# %% [markdown]
# # Erosion

# %%
img = load_img()
kernel = np.ones((5,5),np.uint8)
erosion5 = cv2.erode( img,kernel,iterations = 4)

# %%
display_img(erosion5)

# %% [markdown]
# # Dilation

# %%
img = load_img()
kernel = np.ones((5,5),np.uint8)
dilation5 = cv2.dilate(img, kernel, iterations = 4)

# %%
display_img(dilation5)
